# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#Lendo a base de dados

Base_dados = pd.read_csv('StudentsPerformance+(1).csv')

#Dimensão

Base_dados.shape
# Out:
# (1000, 8)

# %%
#Head

Base_dados.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Campos nulos

Nulos = Base_dados.isnull()

plt.figure(figsize=(16,5 ) )
plt.title('Analise campos nulos')
sns.heatmap(Nulos, cbar=False);

# %%
Base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
Nulos.sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#Únicos

Base_dados.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
Base_dados.duplicated().sum()
# Out:
# 0

# %%
#Estatística

Base_dados.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
Base_dados['gender'].value_counts(normalize=True)*100
# Out:
# female    51.8
# male      48.2
# Name: gender, dtype: float64

# %%
Base_dados['race/ethnicity'].value_counts(normalize=True)*100
# Out:
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: race/ethnicity, dtype: float64

# %%
Base_dados['parental level of education'].value_counts(normalize=True)*100
# Out:
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: parental level of education, dtype: float64

# %%
Base_dados['lunch'].value_counts(normalize=True)*100
# Out:
# standard        64.5
# free/reduced    35.5
# Name: lunch, dtype: float64

# %%
Base_dados['test preparation course'].value_counts(normalize=True)*100
# Out:
# none         64.2
# completed    35.8
# Name: test preparation course, dtype: float64

# %%
Base_dados['math score'].value_counts()
# Out:
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: math score, Length: 81, dtype: int64

# %%
Base_dados['reading score'].value_counts()
# Out:
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# 17     1
# 32     1
# 40     1
# Name: reading score, Length: 72, dtype: int64

# %%
Base_dados['writing score'].value_counts()
# Out:
# 74    35
# 70    33
# 68    31
# 73    28
# 80    27
#       ..
# 28     1
# 35     1
# 19     1
# 22     1
# 23     1
# Name: writing score, Length: 77, dtype: int64

# %%
sns.boxplot(data=Base_dados, x = 'math score', y = 'gender');

# %%
sns.boxplot(data=Base_dados, x = 'reading score', y = 'gender');

# %%
sns.boxplot(data=Base_dados, x = 'writing score', y = 'gender');

# %%
Base_dados.groupby(by=['gender']).describe()['math score'].reset_index()
# Out:
#    gender  count       mean        std   min   25%   50%   75%    max
# 0  female  518.0  63.633205  15.491453   0.0  54.0  65.0  74.0  100.0
# 1    male  482.0  68.728216  14.356277  27.0  59.0  69.0  79.0  100.0

# %%
sns.pairplot(Base_dados, hue='race/ethnicity');

# %%
sns.boxplot(data=Base_dados,x='math score',y='race/ethnicity');

# %%
sns.boxplot(data=Base_dados,x='math score',y='parental level of education');

# %%
Base_dados.groupby(by =['parental level of education']).describe()['math score'].reset_index()
# Out:
#   parental level of education  count       mean        std   min    25%   50%  \
# 0          associate's degree  222.0  67.882883  15.112093  26.0  57.00  67.0
# 1           bachelor's degree  118.0  69.389831  14.943789  29.0  61.00  68.0
# 2                 high school  196.0  62.137755  14.539651   8.0  53.75  63.0
# 3             master's degree   59.0  69.745763  15.153915  40.0  55.50  73.0
# 4                some college  226.0  67.128319  14.312897  19.0  59.00  67.5
# 5            some high school  179.0  63.497207  15.927989   0.0  53.00  65.0
#
#     75%    max
# 0  80.0  100.0
# 1  79.0  100.0
# 2  72.0   99.0
# 3  81.0   95.0
# 4  76.0  100.0
# 5  74.0   97.0

# %%
sns.boxplot(data=Base_dados,x='math score',y='test preparation course');

# %%
Base_dados.groupby(by =['test preparation course']).describe()['math score'].reset_index()
# Out:
#   test preparation course  count       mean        std   min   25%   50%  \
# 0               completed  358.0  69.695531  14.444699  23.0  60.0  69.0
# 1                    none  642.0  64.077882  15.192376   0.0  54.0  64.0
#
#      75%    max
# 0  79.00  100.0
# 1  74.75  100.0

# %%
g = sns.JointGrid(data=Base_dados,x="math score",y="writing score", hue="gender")
g.plot(sns.scatterplot, sns.histplot);

# %%
g = sns.JointGrid(data=Base_dados,x="math score",y="writing score", hue="test preparation course")
g.plot(sns.scatterplot, sns.histplot);

# %%
#ANALISES EXTRAS

Analise_race_reading = Base_dados.groupby( by = ['race/ethnicity']).sum()['reading score'].reset_index().sort_values('reading score', ascending = False)

Analise_race_reading.head()
# Out:
#   race/ethnicity  reading score
# 2        group C          22044
# 3        group D          18348
# 1        group B          12797
# 4        group E          10224
# 0        group A           5756

# %%
Analise_race_math = Base_dados.groupby( by = ['race/ethnicity']).sum()['math score'].reset_index().sort_values('math score', ascending = False)

Analise_race_math.head()
# Out:
#   race/ethnicity  math score
# 2        group C       20564
# 3        group D       17649
# 1        group B       12056
# 4        group E       10335
# 0        group A        5485

# %%
Analise_race_writing = Base_dados.groupby( by = ['race/ethnicity']).sum()['writing score'].reset_index().sort_values('writing score', ascending = False)

Analise_race_writing.head()
# Out:
#   race/ethnicity  writing score
# 2        group C          21637
# 3        group D          18378
# 1        group B          12464
# 4        group E           9997
# 0        group A           5578

# %%
Analise_race_writing.loc[
    Analise_race_writing['race/ethnicity'] == 'group C']
# Out:
#   race/ethnicity  writing score
# 2        group C          21637

# %%
Analise_race_writing = Base_dados.groupby( by = ['gender']).sum()['writing score'].reset_index().sort_values('writing score', ascending = False)

Analise_race_writing.head()
# Out:
#    gender  writing score
# 0  female          37538
# 1    male          30516

# %%
Analise_race_writing = Base_dados.groupby( by = ['gender']).count()['writing score'].reset_index().sort_values('writing score', ascending = False)

Analise_race_writing.head()
# Out:
#    gender  writing score
# 0  female            518
# 1    male            482

# %%
Analise_race_writing = Base_dados.groupby( by = ['lunch']).count()['writing score'].reset_index().sort_values('writing score', ascending = False)

Analise_race_writing.head()
# Out:
#           lunch  writing score
# 1      standard            645
# 0  free/reduced            355

# %%
Analise_geral = Base_dados.loc[(Base_dados['gender'] == 'male') & (Base_dados['race/ethnicity'] == 'group A')].groupby( by = ['gender']).sum()['writing score']

Analise_geral
# Out:
# gender
# male    3135
# Name: writing score, dtype: int64

# %%
Analise_geral_2 = Base_dados.loc[(Base_dados['gender']=='female') & (Base_dados['parental level of education'] =='high school')]#.groupby( by = ['gender']).count()['math score']
Analise_geral_2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 12   female        group B                 high school      standard
# 47   female        group C                 high school      standard
# 55   female        group C                 high school  free/reduced
# 125  female        group B                 high school      standard
# ..      ...            ...                         ...           ...
# 949  female        group E                 high school  free/reduced
# 958  female        group D                 high school      standard
# 972  female        group A                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
Analise_geral_3 = Base_dados.loc[(Base_dados['test preparation course']=='completed') & (Base_dados['parental level of education'] == 'some high school')].groupby( by = ['test preparation course']).count()['writing score']
Analise_geral_3
# Out:
# test preparation course
# completed    77
# Name: writing score, dtype: int64

# %%
Analise_geral_4 = Base_dados.loc[(Base_dados['race/ethnicity']=='group D') & (Base_dados['parental level of education']=='some college') ].groupby(by = ['race/ethnicity']).count()['reading score'] 
Analise_geral_4
# Out:
# race/ethnicity
# group D    67
# Name: reading score, dtype: int64
